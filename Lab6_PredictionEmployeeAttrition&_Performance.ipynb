# %% [markdown]
# <a href="https://colab.research.google.com/github/chaiyawat19/DataScinceLab/blob/main/Lab6_PredictionEmployeeAttrition%26_Performance.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

df = pd.read_csv('/content/HR-Employee-Attrition.csv')

# %%
df.head()

# %% [markdown]
# ดูข้อมูล Balance ของการลาออก Attrition
#
# 1.   Yes = ลาออก
# 2.   ์No = ไม่ลาออก

# %%
sns.countplot(x='Attrition', data=df)

# %% [markdown]
# ให้วิเคราะห์ว่าควร Drop/Reduce ต้องการลดรูปข้อมูล Feature อย่างไรบ้าง

# %% [markdown]
# ก่อนลดรูป ให้สังเกตุว่าใช้ column อะไรบ้าง

# %%
df.columns

# %%
df.dtypes

# %% [markdown]
# ยกตัวอย่างคำสั่ง drop คือไม่เอา columns นั้น

# %%
df.drop(['EmployeeCount', 'EmployeeNumber', 'Over18', 'StandardHours'], axis="columns", inplace=True)

# %% [markdown]
# หลังการ drop ตรวจสอบ

# %%
df.columns

# %% [markdown]
# มีค่าข้อมูลเป็น object

# %%
categorical_col = []
for column in df.columns:
    if df[column].dtype == object and len(df[column].unique()) <= 50:
        categorical_col.append(column)

# %% [markdown]
# ตรวจสอบ column ที่จะเป็น object

# %%
categorical_col

# %% [markdown]
# จัดการการแปลง ให้เป็น labelEncoder

# %%
from sklearn.preprocessing import LabelEncoder

label = LabelEncoder()
for column in categorical_col:
    df[column] = label.fit_transform(df[column])

# %%
df.head(10)

# %%
df['Attrition'] = df.Attrition.astype("category")

# %% [markdown]
# เริ่มสร้าง KNN Model

# %%
from sklearn.model_selection import train_test_split

X = df.drop('Attrition', axis=1)
y = df.Attrition

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# %%
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report

def print_score(clf, X_train, y_train, X_test, y_test, train=True):
    if train:
        pred = clf.predict(X_train)
        clf_report = pd.DataFrame(classification_report(y_train, pred, output_dict=True))
        print("Train Result:\n================================================")
        print(f"Accuracy Score: {accuracy_score(y_train, pred) * 100:.2f}%")
        print("_______________________________________________")
        print(f"CLASSIFICATION REPORT:\n{clf_report}")
        print("_______________________________________________")
        print(f"Confusion Matrix: \n {confusion_matrix(y_train, pred)}\n")

    elif train==False:
        pred = clf.predict(X_test)
        clf_report = pd.DataFrame(classification_report(y_test, pred, output_dict=True))
        print("Test Result:\n================================================")
        print(f"Accuracy Score: {accuracy_score(y_test, pred) * 100:.2f}%")
        print("_______________________________________________")
        print(f"CLASSIFICATION REPORT:\n{clf_report}")
        print("_______________________________________________")
        print(f"Confusion Matrix: \n {confusion_matrix(y_test, pred)}\n")

# %% [markdown]
# ให้นักศึกษาลองปรับพารามิเตอร์ เช่น k โดยที่ คำสั่ง  KNeighborsClassifier(n_neighbors=1) คือ 1-nn

# %%
from sklearn.neighbors import KNeighborsClassifier

tree_clf = KNeighborsClassifier(n_neighbors=1)
tree_clf.fit(X_train, y_train)

print_score(tree_clf, X_train, y_train, X_test, y_test, train=True)
print_score(tree_clf, X_train, y_train, X_test, y_test, train=False)
